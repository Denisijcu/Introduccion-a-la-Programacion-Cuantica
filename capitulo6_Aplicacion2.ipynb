# %%
#Capítulo #6 Aplicaciones del Mundo Real de la Computación Cuántica

#Aplicacion 2: Simulación Cuántica en Química y Materiales

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import Sampler
from qiskit.visualization import plot_histogram

# Crear un circuito cuántico para el Algoritmo de Grover
circuit = QuantumCircuit(2, 2)

# Aplicar Hadamard a los qubits
circuit.h([0, 1])

# Aplicar la puerta CZ para marcar la solución
circuit.cz(0, 1)

# Aplicar Hadamard nuevamente
circuit.h([0, 1])

# Medir los qubits
circuit.measure([0, 1], [0, 1])

# Ejecutar en un simulador
sampler = Sampler()
job = sampler.run(circuit, shots=1024)
result = job.result()

# Mostrar los resultados
counts = result.quasi_dists[0].binary_probabilities()
print(f"Resultados del Algoritmo de Grover: {counts}")

# Dibujar el circuito
circuit.draw(output='mpl')

# Visualizar los resultados en un histograma
plot_histogram(counts)
# Out:
# Resultados del Algoritmo de Grover: {'00': np.float64(0.2705078125), '01': np.float64(0.244140625), '10': np.float64(0.228515625), '11': np.float64(0.2568359375)}
# C:\Users\denis\AppData\Local\Temp\ipykernel_27320\972822476.py:21: DeprecationWarning: The class ``qiskit.primitives.sampler.Sampler`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseSamplerV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Sampler` class is `StatevectorSampler`.
#   sampler = Sampler()
