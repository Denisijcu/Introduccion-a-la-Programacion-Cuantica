# %%
#Capitulo 7. El Futuro de la Computacion Cuantica
#Ejemplo 1 Ejemplo de Simulación de Qubits en Crecimiento:

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import Sampler
from qiskit.visualization import plot_histogram

# Simulación con 5 qubits
circuit = QuantumCircuit(5, 5)

# Aplicar Hadamard a todos los qubits
circuit.h(range(5))

# Medir todos los qubits
circuit.measure(range(5), range(5))

# Ejecutar en un simulador
sampler = Sampler()
job = sampler.run(circuit, shots=1024)
result = job.result()

# Mostrar los resultados
counts = result.quasi_dists[0].binary_probabilities()
print(f"Resultados: {counts}")

# Visualizar los resultados
plot_histogram(counts)
# Out:
# C:\Users\denis\AppData\Local\Temp\ipykernel_28564\3132208523.py:15: DeprecationWarning: The class ``qiskit.primitives.sampler.Sampler`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseSamplerV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Sampler` class is `StatevectorSampler`.
#   sampler = Sampler()
# ...
